# %%
import dill
from src import config as cfg

# %%
model_name = 'xgb_1.1'

with open(f'{cfg.models_path}/model_{model_name}_last.pkl', 'rb') as f:
    model = dill.load(f)
model.log
# Out:
#              timestamp      time  train_score  test_score  \
# 0  14-05-2021 16:53:24  0.091234    11.350026   11.409281
# 1  14-05-2021 16:53:27  0.036128    11.003061   11.060878
# 2  14-05-2021 16:53:38  0.186314     4.377472    4.351448
# 3  14-05-2021 16:53:46  0.130636     5.740432    5.749904
# 4  14-05-2021 16:53:51  0.079252    11.162873   11.221369
#
#                                      hyperparam_dict   booster     gamma  \
# 0  {'booster': 'gbtree', 'gamma': 0.3264884013274...    gbtree  0.326488
# 1  {'booster': 'gbtree', 'gamma': 1.9886487825963...    gbtree  1.988649
# 2  {'booster': 'gblinear', 'gamma': 0.25835379843...  gblinear  0.258354
# 3  {'booster': 'gblinear', 'gamma': 1.43002228292...  gblinear  1.430022
# 4  {'booster': 'gbtree', 'gamma': 0.6866341783647...    gbtree  0.686634
#
#    learning_rate  max_delta_step  max_depth  min_child_weight  n_estimators  \
# 0       0.886906             1.0        3.0               3.0        6000.0
# ...
